# %%
#Analysis:
#Fig.1. The highest temperature above 100F are recorded at latitude 20-40N instead of the equator.
#2.The most likely reason is highly populated land masses and anthropogenic emissions.
#3. Lowest temperatures are observed towards poles but no data is avaialble for Greenland and Southpole.Total votes: {Total_votes}")

#Fig.2. point.4. Relative humidity is higher at 20-40 latitude on both Northen and Southern part of the globe.
#This trend is due to the "Trade Winds" which carry moisture from the ocean towards land.
#5. A plot of humidity versus latitude indicates a nice "camel-hump" which indicates that relative humidity level is low in the equatorial regions. 

#Fig. 3 & 4. No trend is observed for wind speed and cloud cover on the globe.

#Fig. 5.shows inverse relatioship between temperature and humidity. 
# the most likely cause is the ability of air to hold water vapors reduces at higher temperature.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests as req
import time
import json
import csv
from datetime import datetime as dt
import os
# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
#country_code= []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
   # If the city is unique, then add it to a our cities list, it has to be in the loop withing the indeneted sapce to check each city as being addeed to the list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm <500 countries were generated
len(cities)
# Out:
# 609

# %% [markdown]
# ## Perform API Calls

# %%
## to perform API call,buidling a URL
#default unit is imperical, otherwise an additional key for "units" can be added.


weather_key=api_keys.api_key
URL="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_key

citi_weather=[]

for city in cities:
    city_URL=URL+'&q='+city
    #print("processing record for the city %s.URL: %s" % (city, city_URL))
    print('processing record for the city %s'%city)
    
    #For date in the city_data, I tried to build a subloop but it did not work
    #for date in city_data:
    # https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
    # http://strftime.org/
    #converted_time = datetime.strptime(raw_time, "%a %b %d %H:%M:%S %z %Y")
    #converted_timestamps.append(converted_time)
        
    try:

        city_data=req.get(city_URL).json()
        city_lat=city_data["coord"]["lat"]
        city_lon=city_data["coord"]["lon"]
        city_temp=city_data["main"]["temp"]
        city_hum=city_data["main"]["humidity"]
        city_pr=city_data["main"]["pressure"]
        city_ws=city_data["wind"]["speed"]
        city_cl=city_data["clouds"]["all"]
        city_cc=city_data["sys"]["country"]
        city_date=city_data["dt"]

        citi_weather.append({"city":city, 
        "latitude":city_lat,
        "longitude":city_lon,
        "temperature":city_temp,
        "humidity":city_hum,
        "pressure":city_pr,
        "wind speed":city_ws,
        "clouds":city_cl,
        "country code":city_cc,
        "Date":city_date
})
    except:
        print('city not found')
    pass
# Out:
# processing record for the city sentyabrskiy
# city not found
# processing record for the city ushuaia
# processing record for the city puerto ayora
# processing record for the city siuna
# processing record for the city tiksi
# processing record for the city labytnangi
# processing record for the city illoqqortoormiut
# city not found
# processing record for the city ambam
# processing record for the city hambantota
# processing record for the city saskylakh
# processing record for the city atuona
# processing record for the city hermanus
# processing record for the city fortuna
# processing record for the city seoul
# processing record for the city bokspits
# city not found
# processing record for the city vaini
# processing record for the city pisco
# processing record for the city khorixas
# processing record for the city rikitea
# processing record for the city arraial do cabo
# processing record for the city hilo
# processing record for the city grand gaube
# processing record for the city lolua
# city not found
# processing record for the city karratha
# processing record for the city umm lajj
# processing record for the city bredasdorp
# processing record for the city qaanaaq
# processing record for the city upernavik
# processing record for the city hervey bay
# processing record for the city barrow
# processing record for the city lieto
# processing record for the city attawapiskat
# processing record for the city caravelas
# processing record for the city sioux lookout
# processing record for the city likhoslavl
# processing record for the city lewisporte
# processing record for the city te anau
# processing record for the city thai binh
# processing record for the city parati
# processing record for the city huanren
# processing record for the city oga
# processing record for the city pangnirtung
# processing record for the city nouadhibou
# processing record for the city aksha
# processing record for the city morant bay
# processing record for the city nosy varika
# processing record for the city mae sot
# processing record for the city shingu
# processing record for the city ust-tsilma
# processing record for the city saint-pierre
# processing record for the city korla
# city not found
# processing record for the city kiama
# processing record for the city mackay
# processing record for the city saleaula
# city not found
# processing record for the city hampden
# processing record for the city constitucion
# processing record for the city kabinda
# processing record for the city tupiza
# processing record for the city torbay
# processing record for the city homer
# processing record for the city poum
# processing record for the city westport
# processing record for the city kindu
# processing record for the city dali
# processing record for the city aquiraz
# processing record for the city namatanai
# processing record for the city miragoane
# processing record for the city blackwater
# processing record for the city zhigalovo
# processing record for the city talah
# city not found
# processing record for the city iquitos
# processing record for the city hirara
# processing record for the city villefranche-de-rouergue
# processing record for the city fatikchhari
# city not found
# processing record for the city panama city
# processing record for the city hede
# processing record for the city feijo
# processing record for the city kungurtug
# processing record for the city porto santo
# city not found
# processing record for the city batemans bay
# processing record for the city azrow
# city not found
# processing record for the city pyay
# processing record for the city college
# processing record for the city semnan
# processing record for the city rusape
# processing record for the city berlevag
# processing record for the city jiexiu
# processing record for the city tres lagoas
# city not found
# processing record for the city havoysund
# processing record for the city labuhan
# processing record for the city baykit
# processing record for the city serebryanyy bor
# processing record for the city zemio
# processing record for the city shimoda
# processing record for the city chililabombwe
# processing record for the city shihezi
# processing record for the city milkovo
# processing record for the city solikamsk
# processing record for the city esso
# processing record for the city bilibino
# processing record for the city verkhnyaya inta
# processing record for the city ostersund
# processing record for the city luis correia
# processing record for the city qaqortoq
# processing record for the city lewiston
# processing record for the city cabangahan
# processing record for the city mount gambier
# processing record for the city bandar
# processing record for the city komsomolskiy
# processing record for the city whitehorse
# processing record for the city sorland
# processing record for the city yanahuanca
# processing record for the city jakar
# processing record for the city khash
# processing record for the city dromolaxia
# processing record for the city montlucon
# processing record for the city gigmoto
# processing record for the city acapulco
# processing record for the city redwater
# processing record for the city richards bay
# processing record for the city rio pomba
# processing record for the city talovaya
# processing record for the city comodoro rivadavia
# processing record for the city madang
# processing record for the city mana
# processing record for the city asau
# city not found
# processing record for the city van buren
# processing record for the city bokoro
# city not found
# processing record for the city sosnogorsk
# processing record for the city taburi
# city not found
# processing record for the city ambovombe
# processing record for the city dingle
# processing record for the city luebo
# processing record for the city kyren
# processing record for the city sisophon
# processing record for the city liling

# %%
#create csv file"cities" in a folder named output_file
#convert to dataframe first and save as csv file
city_data_df=pd.DataFrame(citi_weather)
latitude= city_data_df["latitude"]
longitude=city_data_df["longitude"]
temperature=city_data_df["temperature"]
humidity=city_data_df["humidity"]
pressure=city_data_df["pressure"]
wind_speed=city_data_df["wind speed"]
clouds=city_data_df["clouds"]
country=city_data_df["country code"]
date=city_data_df['Date'] 

city_data_df.head()        


#city_data_df.to_csv("output_data/cities.csv")
# Out:
#          Date          city  clouds country code  humidity  latitude  \
# 0  1533679200       ushuaia      20           AR       100    -54.81
# 1  1533679200  puerto ayora       0           EC        57     -0.74
# 2  1533684147         siuna      76           NI        87     13.73
# 3  1533684147         tiksi       0           RU        78     71.64
# 4  1533684148    labytnangi      92           RU        98     66.66
#
#    longitude  pressure  temperature  wind speed
# 0     -68.31   1018.00        32.00       10.29
# 1     -90.35   1009.00        78.80       19.46
# 2     -84.78   1003.26        77.33        3.78
# 3     128.87   1013.39        52.85        7.52
# 4      66.39   1002.86        55.82        7.92

# %%
# to save city data as csv in output folder
city_data_df.to_csv("output_data/cities.csv")

# %%
city_data_df.dtypes
# Out:
# Date              int64
# city             object
# clouds            int64
# country code     object
# humidity          int64
# latitude        float64
# longitude       float64
# pressure        float64
# temperature     float64
# wind speed      float64
# dtype: object

# %%
#to check number of cities imported through citipy with weather parameters, should be >500.
city_data_df.count()
# Out:
# Date            548
# city            548
# clouds          548
# country code    548
# humidity        548
# latitude        548
# longitude       548
# pressure        548
# temperature     548
# wind speed      548
# dtype: int64

# %%
# Build a scatter plot for each data type
plt.scatter(city_data_df["latitude"], city_data_df["temperature"], marker="o", color="blue")

# Incorporate the other graph properties
plt.title("Fig. 1. Temperature of World Cities on Aug 08,2018")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitide")
plt.grid(linestyle="dashed")
plt.ylim(-1,130)
plt.xlim(-90,90)
plt.xticks(rotation='horizontal')
plt.axvline(x=0, color = 'black',linestyle="dashed") #adds a vertical line at the equator
# Save the figure
plt.savefig("temperatureofWorldCities.png")

# Show plot
plt.show()

# %%
print("Results")
print("Fig. 1. The highest temperature, above 100F is observed at 20-40 degree latitude instead of the equator as anticipated")
print("The most likely cause, heat dissipation through rain, is higher at the equator")
print("The lowest temperatures are observed towards poles but no data is avaialble for the north pole which is Greenland and the Southpole")


#Fig. 4.shows inverse relatioship between temperature and humidity. At higher temperature, the ability of air to hold water vapors reduces.
# Out:
# Results
# Fig. 1. The highest temperature, above 100F is observed at 20-40 degree latitude instead of the equator as anticipated
# The most likely cause, heat dissipation through rain, is higher at the equator
# The lowest temperatures are observed towards poles but no data is avaialble for the north pole which is Greenland and the Southpole

# %%
# Build a scatter plot for each data type
plt.scatter(city_data_df["latitude"], city_data_df["humidity"], marker="o", color="green")

# Incorporate the other graph properties
plt.title("Fig. 2. Humidity of World Cities on Aug 08,2018")
plt.ylabel("Humidity")
plt.xlabel("Latitide")
plt.grid(linestyle="dashed")
plt.ylim(-1,110)
plt.xlim(-90,90)
plt.xticks(rotation='horizontal')
plt.axvline(x=0, color = 'black',linestyle="dashed") #adds a vertical line at the equator
# Save the figure
plt.savefig("HumidityofWorldCities.png")

# Show plot
plt.show()

# %%
#print("Results")
#print("Fig.2. The relative humidity show maxima at 20-40 latitude on both Northen and Southern part of the globe")
#print("This trend is due to the "Trade Winds" which carry moisture from the ocean towards land").
#print("A plot of humidity versus latitude indicates a nice "camel-hump" 
#which indicates that relative humidity level is low in the equatorial regions").

# %%
# Build a scatter plot for each data type
plt.scatter(city_data_df["latitude"], city_data_df["clouds"], marker="o", color="blue")

# Incorporate the other graph properties
plt.title("Fig. 3. cloud cover of World Cities on Aug 08,2018", fontdict = {'fontsize': 11, 'fontweight': 'bold'})
plt.ylabel("Cloudiness")
plt.xlabel("Latitide")
plt.grid(linestyle="dashed")
plt.ylim(-1,110)
plt.xlim(-90,90)

# Save the figure
plt.savefig("CloudCoverofWorldCities.png")

# Show plot
plt.show()

# %%
#print("Resulsts from fig. 3.")
#print("No trend is observed for wind speed and cloud cover on the globe)

# %%
# Build a scatter plot for each data type
plt.scatter(city_data_df["latitude"], city_data_df["wind speed"], marker="o", color="red")

# Incorporate the other graph properties
plt.title("Fig. 4. Wind speed of World Cities on Aug 08,2018",fontdict = {'fontsize': 11, 'fontweight': 'bold'})
plt.ylabel("wind speed")
plt.xlabel("Latitide")
plt.grid(linestyle="dashed")
plt.ylim(-1,40)
plt.xlim(-90,90)
plt.xticks(rotation='horizontal')
plt.axvline(x=0, color = 'black',linestyle="dashed") #adds a vertical line at the equator
# Save the figure
plt.savefig("windspeedofWorldCities.png")

# Show plot
plt.show()

# %%
#print("Resulsts from fig. 4.")
#print("No trend is observed for wind speed versus latitude.
#A likely pattern can be inferred that 20-40S and 20-40N shows Eastely and Westerly winds 
# and polar jet at 60N.

# %%
#to observe effect of clouds on Temperature
# Build a scatter plot for each data type
plt.scatter(city_data_df["temperature"], city_data_df["humidity"], marker="^", color="red")

# Incorporate the other graph properties
plt.title("Fig. 5. Effect of temperature on Humidity levels on Aug 08,2018",fontdict = {'fontsize': 11, 'fontweight': 'bold'})
plt.ylabel("Humidity")
plt.xlabel("Temperature (F)")
plt.grid(linestyle="dashed")
plt.ylim(-1,110)
plt.xlim(-0,120)
#plt.xticks(rotation='horizontal')
#plt.axvline(x=0, color = 'black',linestyle="dashed") #adds a vertical line at the equator
# Save the figure
plt.savefig("temp and humidity ofWorldCities.png")

# Show plot
plt.show()

# %%
#Fig. 5.shows inverse relatioship between temperature and humidity. 
# the most likely cause is the ability of air to hold water vapors reduces at higher temperature.

# %%
# display results in .txt file
output_file = os.path.join("output_data", "WeatherPy_Results.txt")
with open(output_file, "w") as datafile:
    datafile.write("WeatherPy Results.\n")
    datafile.write("Highest temperature recorded at mid-latitude shown inFig.1\n")
    datafile.write("No trend observed for cloud and wind with latitude Fig.3-4\n")
    datafile.write("Humidity decreases with temperature as shown in Fig.5.\n")
    datafile.write("grouping/binning based on temperature and relative humidity is needed.\n")
    

   
   

# print out contents of .txt file in terminal
with open(output_file, "r") as f:
   results = f.read()
   print(results)
# Out:
# WeatherPy Resultsas.
# Highest temperature recorded at mid-latitude shown inFig.1
# No trend observed for cloud and wind with latitude Fig.3-4
# Humidity decreases wit temperature as shown in Fig.5.
# grouping/binning based on temperature and relative humidity is needed.
