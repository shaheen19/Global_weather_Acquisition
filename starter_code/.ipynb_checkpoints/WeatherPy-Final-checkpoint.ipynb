# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests as req
import time
import json
import csv
from datetime import datetime as dt
import os
# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
#country_code= []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
   # If the city is unique, then add it to a our cities list, it has to be in the loop withing the indeneted sapce to check each city as being addeed to the list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm <500 countries were generated
len(cities)
# Out:
# 614

# %%
## set up additional columns to hold information
#City_df["City"] = ""
#City_df["Country"] = ""
#City_df.set_value(index, "City", city)
#City_df.set_value(index, "Country", country)

weather_key=api_keys.api_key
URL="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_key
#URL="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_key
citi_weather=[]

for city in cities:
    city_URL=URL+'&q='+city
    #print("processing record for the city %s.URL: %s" % (city, city_URL))
    print('processing record for the city %s'%city)
    #for date in city_data:
    # https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
    # http://strftime.org/
    #converted_time = datetime.strptime(raw_time, "%a %b %d %H:%M:%S %z %Y")
    #converted_timestamps.append(converted_time)
        
    try:

        city_data=req.get(city_URL).json()
        city_lat=city_data["coord"]["lat"]
        city_lon=city_data["coord"]["lon"]
        city_temp=city_data["main"]["temp"]
        city_hum=city_data["main"]["humidity"]
        city_pr=city_data["main"]["pressure"]
        city_ws=city_data["wind"]["speed"]
        city_cl=city_data["clouds"]["all"]
        city_cc=city_data["sys"]["country"]
        city_date=city_data["dt"]

        citi_weather.append({"city":city, 
        "latitude":city_lat,
        "longitude":city_lon,
        "temperature":city_temp,
        "humidity":city_hum,
        "pressure":city_pr,
        "wind speed":city_ws,
        "clouds":city_cl,
        "country code":city_cc,
        "Date":city_date
})
    except:
        print('city not found')
    pass
# Out:
# processing record for the city bardiyah
# city not found
# processing record for the city salekhard
# processing record for the city sechura
# processing record for the city ushuaia
# processing record for the city hermanus
# processing record for the city lagoa
# processing record for the city besancon
# processing record for the city cape town
# processing record for the city hobart
# processing record for the city port hedland
# processing record for the city yumen
# processing record for the city new norfolk
# processing record for the city kavieng
# processing record for the city uyuni
# processing record for the city albany
# processing record for the city ambanja
# processing record for the city labutta
# city not found
# processing record for the city kiama
# processing record for the city jalu
# processing record for the city taolanaro
# city not found
# processing record for the city ponta delgada
# processing record for the city le port
# processing record for the city biak
# processing record for the city qaanaaq
# processing record for the city henties bay
# processing record for the city aleksandrovsk-sakhalinskiy
# processing record for the city kaitangata
# processing record for the city ponta do sol
# processing record for the city mataura
# processing record for the city fairbanks
# processing record for the city sentyabrskiy
# city not found
# processing record for the city sedelnikovo
# city not found
# processing record for the city carnarvon
# processing record for the city ugoofaaru
# processing record for the city illoqqortoormiut
# city not found
# processing record for the city huarmey
# processing record for the city les escoumins
# processing record for the city erenhot
# processing record for the city bluff
# processing record for the city nikolskoye
# processing record for the city sorong
# processing record for the city dodola
# processing record for the city kamenka
# processing record for the city atuona
# processing record for the city naze
# processing record for the city kodiak
# processing record for the city iskateley
# processing record for the city erdenet
# processing record for the city sinnamary
# processing record for the city tezu
# processing record for the city anloga
# processing record for the city busselton
# processing record for the city mme
# city not found
# processing record for the city chuy
# processing record for the city iqaluit
# processing record for the city guiyang
# processing record for the city avarua
# processing record for the city grindavik
# processing record for the city luderitz
# processing record for the city myitkyina
# processing record for the city yellowknife
# processing record for the city ketchikan
# processing record for the city vostok
# processing record for the city punta arenas
# processing record for the city rikitea
# processing record for the city rapallo
# processing record for the city tuktoyaktuk
# processing record for the city georgetown
# processing record for the city kahului
# processing record for the city oksfjord
# processing record for the city broken hill
# processing record for the city santa cruz
# processing record for the city grand river south east
# city not found
# processing record for the city boffa
# processing record for the city hilo
# processing record for the city sile
# processing record for the city cidreira
# processing record for the city vestmanna
# processing record for the city rocha
# processing record for the city upernavik
# processing record for the city baykit
# processing record for the city amderma
# city not found
# processing record for the city port alfred
# processing record for the city norman wells
# processing record for the city sitka
# processing record for the city tilichiki
# processing record for the city yen bai
# processing record for the city umzimvubu
# city not found
# processing record for the city dingle
# processing record for the city carbonia
# processing record for the city atasu
# processing record for the city karratha
# processing record for the city tuatapere
# processing record for the city clyde river
# processing record for the city asosa
# processing record for the city pisco
# processing record for the city esperance
# processing record for the city otane
# processing record for the city klyuchi
# processing record for the city san patricio
# processing record for the city moussoro
# processing record for the city juneau
# processing record for the city olga
# processing record for the city mahebourg
# processing record for the city namatanai
# processing record for the city tutoia
# processing record for the city mys shmidta
# city not found
# processing record for the city vaini
# processing record for the city el balyana
# city not found
# processing record for the city hasaki
# processing record for the city dosso
# processing record for the city luanda
# processing record for the city barentsburg
# city not found
# processing record for the city san buenaventura
# processing record for the city jega
# processing record for the city tsihombe
# city not found
# processing record for the city auki
# processing record for the city vila franca do campo
# processing record for the city hithadhoo
# processing record for the city miesbach
# processing record for the city kerteh
# city not found
# processing record for the city bredasdorp
# processing record for the city ribeira grande
# processing record for the city sao filipe
# processing record for the city senneterre
# processing record for the city castro
# processing record for the city barrow
# processing record for the city port elizabeth
# processing record for the city tasiilaq
# processing record for the city grand-lahou
# processing record for the city monte alegre
# processing record for the city paragould
# processing record for the city port hardy
# processing record for the city orgun
# city not found
# processing record for the city balykshi
# city not found
# processing record for the city ahipara
# processing record for the city acarau
# city not found
# processing record for the city parakou
# processing record for the city bagdarin
# processing record for the city shingu
# processing record for the city east london
# processing record for the city belushya guba
# city not found
# processing record for the city roma
# processing record for the city khatanga
# processing record for the city tabory
# processing record for the city yatsuo
# processing record for the city rio grande
# processing record for the city kapaa
# processing record for the city skjervoy
# processing record for the city jamestown
# processing record for the city santarem
# city not found
# processing record for the city beyneu
# processing record for the city puerto ayora
# processing record for the city mastic beach
# processing record for the city husavik
# processing record for the city touros
# processing record for the city haines junction
# processing record for the city valparaiso
# processing record for the city commerce
# processing record for the city aykhal
# processing record for the city malwan
# city not found
# processing record for the city tsienyane
# city not found
# processing record for the city aberdeen
# processing record for the city marawi
# processing record for the city dikson
# processing record for the city molepolole
# processing record for the city avera
# processing record for the city lakes entrance
# processing record for the city denpasar
# processing record for the city xining
# processing record for the city awbari
# processing record for the city gigmoto
# processing record for the city new baltimore
# processing record for the city bathsheba
# processing record for the city kargasok
# processing record for the city muros
# processing record for the city verkhnevilyuysk
# processing record for the city palabuhanratu
# city not found
# processing record for the city litovko
# processing record for the city wamba
# processing record for the city susanville
# processing record for the city lompoc
# processing record for the city bengkulu
# city not found
# processing record for the city naters
# processing record for the city ancud
# processing record for the city kudahuvadhoo
# processing record for the city cochrane
# processing record for the city lebu
# processing record for the city baoqing
# processing record for the city vaitupu
# city not found
# processing record for the city karamay
# city not found
# processing record for the city souillac
# processing record for the city pevek
# processing record for the city vaitape
# processing record for the city cairns
# processing record for the city airai
# processing record for the city manokwari
# processing record for the city vardo
# processing record for the city sokolo
# processing record for the city west bay
# processing record for the city ovalle
# processing record for the city lerwick
# processing record for the city neverkino
# processing record for the city porto velho
# processing record for the city manyana
# processing record for the city menongue
# processing record for the city jiwani
# processing record for the city gidole
# processing record for the city chokurdakh
# processing record for the city insar
# processing record for the city bakchar
# processing record for the city dutse
# processing record for the city wulanhaote
# city not found
# processing record for the city muisne
# processing record for the city chapais
# processing record for the city pombas
# processing record for the city tula
# processing record for the city hirado
# processing record for the city saint-denis
# processing record for the city vila velha
# processing record for the city mizdah
# processing record for the city neuquen
# processing record for the city mersing
# processing record for the city lufilufi
# processing record for the city yeppoon
# processing record for the city casambalangan
# processing record for the city villazon
# city not found
# processing record for the city hutchinson
# processing record for the city warmbad
# processing record for the city buturlinovka

# %%
#create csv file"cities" in a folder named output_file
#convert to dataframe first and save as csv file
city_data_df=pd.DataFrame(citi_weather)
latitude= city_data_df["latitude"]
longitude=city_data_df["longitude"]
temperature=city_data_df["temperature"]
humidity=city_data_df["humidity"]
pressure=city_data_df["pressure"]
wind_speed=city_data_df["wind speed"]
clouds=city_data_df["clouds"]
country=city_data_df["country code"]
date=city_data_df['Date'] 

city_data_df.head()        


#city_data_df.to_csv("output_data/cities.csv")
# Out:
#          Date       city  clouds country code  humidity  latitude  longitude  \
# 0  1533651037  salekhard      80           RU        95     66.54      66.62
# 1  1533651037    sechura       0           PE        90     -5.56     -80.82
# 2  1533650887    ushuaia       0           AR       100    -54.81     -68.31
# 3  1533651038   hermanus      56           ZA       100    -34.42      19.24
# 4  1533651038      lagoa       0           PT        43     37.14      -8.45
#
#    pressure  temperature  wind speed
# 0   1004.64        58.70        8.72
# 1   1023.52        67.34        9.62
# 2    983.48        28.73        2.68
# 3   1000.26        46.55        2.91
# 4   1009.74        85.79       11.52

# %%
# to save city data as csv in output folder
city_data_df.to_csv("output_data/cities.csv")

# %%
city_data_df.dtypes
# Out:
# Date              int64
# city             object
# clouds            int64
# country code     object
# humidity          int64
# latitude        float64
# longitude       float64
# pressure        float64
# temperature     float64
# wind speed      float64
# dtype: object

# %%
#to check number of cities imported through citipy with weather parameters 
city_data_df.count()
# Out:
# Date            545
# city            545
# clouds          545
# country code    545
# humidity        545
# latitude        545
# longitude       545
# pressure        545
# temperature     545
# wind speed      545
# dtype: int64

# %%
# Build a scatter plot for each data type
plt.scatter(city_data_df["latitude"], city_data_df["temperature"], marker="o", color="blue")

# Incorporate the other graph properties
plt.title("Fig. 1. Temperature of World Cities on Aug 08,2018")
plt.ylabel("Temperature (Farnheit)")
plt.xlabel("Latitide")
plt.grid(linestyle="dashed")
plt.ylim(-1,110)
plt.xlim(-90,90)
plt.xticks(rotation='horizontal')
plt.axvline(x=0, color = 'black',linestyle="dashed") #adds a vertical line at the equator
# Save the figure
plt.savefig("temperatureofWorldCities.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(city_data_df["latitude"], city_data_df["humidity"], marker="o", color="green")

# Incorporate the other graph properties
plt.title("Fig. 2. Humidity of World Cities on Aug 08,2018")
plt.ylabel("Humidity")
plt.xlabel("Latitide")
plt.grid(linestyle="dashed")
plt.ylim(-1,110)
plt.xlim(-90,90)
plt.xticks(rotation='horizontal')
plt.axvline(x=0, color = 'black',linestyle="dashed") #adds a vertical line at the equator
# Save the figure
plt.savefig("HumidityofWorldCities.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(city_data_df["latitude"], city_data_df["clouds"], marker="o", color="blue")

# Incorporate the other graph properties
plt.title("Fig. 3. cloud cover of World Cities on Aug 08,2018", fontdict = {'fontsize': 11, 'fontweight': 'bold'})
plt.ylabel("Cloudiness")
plt.xlabel("Latitide")
plt.grid(linestyle="dashed")
plt.ylim(-1,110)
plt.xlim(-90,90)

# Save the figure
plt.savefig("CloudCoverofWorldCities.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(city_data_df["latitude"], city_data_df["wind speed"], marker="o", color="red")

# Incorporate the other graph properties
plt.title("Fig. 4. Wind speed of World Cities on Aug 08,2018",fontdict = {'fontsize': 11, 'fontweight': 'bold'})
plt.ylabel("wind speed")
plt.xlabel("Latitide")
plt.grid(linestyle="dashed")
plt.ylim(-1,40)
plt.xlim(-90,90)
plt.xticks(rotation='horizontal')
plt.axvline(x=0, color = 'black',linestyle="dashed") #adds a vertical line at the equator
# Save the figure
plt.savefig("windspeedofWorldCities.png")

# Show plot
plt.show()

# %%
#to observe effect of clouds on Temperature
# Build a scatter plot for each data type
plt.scatter(city_data_df["temperature"], city_data_df["humidity"], marker="^", color="red")

# Incorporate the other graph properties
plt.title("Fig. 5. Effect of temperature on Humidity levels on Aug 08,2018",fontdict = {'fontsize': 11, 'fontweight': 'bold'})
plt.ylabel("Humidity")
plt.xlabel("Temperature (F)")
plt.grid(linestyle="dashed")
plt.ylim(-1,110)
plt.xlim(-0,120)
#plt.xticks(rotation='horizontal')
#plt.axvline(x=0, color = 'black',linestyle="dashed") #adds a vertical line at the equator
# Save the figure
plt.savefig("temp and humidity ofWorldCities.png")

# Show plot
plt.show()

# %%
# display results in .txt file
output_file = os.path.join("output_data", "WeatherPy_Results.txt")
with open(output_file, "w") as datafile:
    datafile.write("WeatherPy_Results\n")
    

   
   

# print out contents of .txt file in terminal
with open(output_file, "r") as f:
   results = f.read()
   print(results)
# Out:
# WeatherPy_Results

# %%
#average_temp = city_data_df.groupby(["temperature"]).mean()["humidity"].rename("Average temperature")
#average_hum = city_data.groupby(["humidity"]).mean()["humidity"].rename("Average temperature")
# Data frame for user_data
#average_temp_data = pd.DataFrame({
                         # "Average temperature": average_temp,
                          #"Average Humidity": average_hum,
                          #})

#average_temp_data
# Display table of top 5 spenders
#average_temp_data.sort_values("", ascending=False).head(5)
groupby_humidity= city_data_df.groupby(['humidity']).mean()["humidity"].rename("Average humidity")
groupby_tempearature=city_data_df.groupby([temperature]).mean()["temperature"].rename("Average temp")
average_data = pd.DataFrame({
                         "Average temperature": average_temp,
                          "Average Humidity": average_hum,
                          })

# Create a DataFrame based on the counts of the groupby object
#cities_counts = groupby_humidity.count()
#cities_counts
average_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'humidity'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-2d8d643b912f> in <module>()
#      10 # Display table of top 5 spenders
#      11 #average_temp_data.sort_values("", ascending=False).head(5)
# ---> 12 groupby_humidity= city_data_df.groupby(['humidity']).mean()["humidity"].rename("Average humidity")
#      13 groupby_tempearature=city_data_df.groupby([temperature]).mean()["temperature"].rename("Average temp")
#      14 average_data = pd.DataFrame({
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'humidity'

# %%
x_axis=city_data_df["latitude"]
y_axis=city_data_df["clouds"]
plt.scatter((x_axis,y_axis)
plt.xlabel('latitude')
plt.ylabel('Cloudiness')
plt.title('Latitude vs Cloud Cover on Aug. 08, 2018', fontdict = {'fontsize': 11, 'fontweight': 'bold'})
plt.savefig('cloudcoverofWorldCities.png')
plt.show()

# %%
#converted_time_=[]
#for date in city_data_df:
    # https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
    # http://strftime.org/
    #date = datetime.strptime(raw_time, "%a %b %d %H:%M:%S %z %Y")
    #converted_timestamps.append(converted_time)

# %%
# Force column order
city_data_df = city_data_df[["city","country","latitude","longitude","temperature","humidity","clouds","wind speed"]]
city_data_df.head()

# %%
city_data_df.to_csv("output_data/cities.csv", encoding="utf-8")

# %%
x_axis=city_data_df["latitude"]
y_axis=city_data_df["temperature"]
plt.scatter((x_axis,y_axis)
plt.xlabel('latitude')
plt.ylabel('Temperature(F)')
plt.title('Latitude vs Temperature' )
plt.savefig('TemperatureofWorldCities.png')
plt.show()
# Build a scatter plot for each data type
#plt.scatter(city["Lat"], City_Sample["Temp"], marker="o", color = 'blue')

# # Incorporate the other graph properties
#plt.title("City Altitude vs Max Temperature " + str(Date))
#plt.ylabel("Max Temperature (F)")
#plt.xlabel("Latitude")
#plt.yticks(np.arange(-40, 120, 20))
#plt.grid(True)
#sns.set_style('darkgrid')

# %%
#p=tucson
#https://openweathermap.org/api
#varibale, fileame, keyanme
# list for response results
#lat=[]
#lon = []
#city = []
#country = []
#temp= []
#humidity=[]
#citi_weather will store all these parameter as one dictionary

weather_key=api_keys.api_key
URL="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_key
citi_weather=[]

for i, city in enumerate(cities):
    city_URL=URL+'&q='+city
    
    print('processing record for the city %s.URL %s'%(city, city_URL))
    
    try:
        city_data=requests.get(city_URL).json()
        city_lat=city_data["coord"]["lat"]
        city_lon=city_data["coord"]["lon"]
        city_temp=city_data["main"]["temp"]
        city_hum=city_data["main"]["humidity"]
        city_pr=city_data["main"]["pressure"]
        city_ws=city_data["wind"]["speed"]
        city_cl=city_data["clouds"]["all"]
        city_cc=city_data["sys"]["country"]
        city_date=city_data["dt"]
        
        
        citi_weather.append({"city":city, 
                             "latitude":city_lat,
                             "longitude":city_lon,
                             "temperature":city_temp,
                             "humidity":city_hum,
                             "pressure":city_pr,
                             "wind speed":city_ws,
                             "clouds":city_cl,
                             "country code":citi_cc,
                             "Date":city_date})
    except:
        print('city not found')
        pass
    

#* Temperature (F) vs. Latitude
#* Humidity (%) vs. Latitude
#* Wind Speed (mph) vs. Latitude

#* Cloudiness (%) vs. Latitude

# add closest city and country column
#location_data['closest_city'] = ""
#location_data['country'] = ""

# %%
#find and add closest city and country code
#for index, row in location_data.iterrows():
    #lat = row['rand_lat']
    #lng = row['rand_lng']
    #location_data.iat(index, 'closest_city', citipy.nearest_city(lat, lng).city_name)
    #location_data.iat(index, 'country', citipy.nearest_city(lat, lng).country_code)
    #print(lat, lng)

# %%
# delete repeated cities and find unique city count
location_data = location_data.drop_duplicates(['closest_city', 'country'])
location_data = location_data.dropna()
len(location_data['closest_city'].value_counts())

# %%
#preview data
location_data.head()

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
