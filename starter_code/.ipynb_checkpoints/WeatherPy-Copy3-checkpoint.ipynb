# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests as req
import time
import json
import csv
from datetime import datetime as dt

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
#country_code= []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    #country= citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
   # If the city is unique, then add it to a our cities list, it has to be in the loop withing the indeneted sapce to check each city as being addeed to the list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count-621 countries were counted
len(cities) 

#country_code=[]
#counter =0
        #for city in cities
            #country_code= city.country_code

#City_df = pd.DataFrame(cities)
#city_df.head()
# Out:
# 623

# %%
## set up additional columns to hold information
#City_df["City"] = ""
#City_df["Country"] = ""
#City_df.set_value(index, "City", city)
#City_df.set_value(index, "Country", country)

weather_key=api_keys.api_key
URL="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_key
#URL="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_key
citi_weather=[]

for city in cities:
    city_URL=URL+'&q='+city
    #print("processing record for the city %s.URL: %s" % (city, city_URL))
    print('processing record for the city %s'%city)
    #for date in city_data:
    # https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
    # http://strftime.org/
    #converted_time = datetime.strptime(raw_time, "%a %b %d %H:%M:%S %z %Y")
    #converted_timestamps.append(converted_time)
        
    try:

        city_data=req.get(city_URL).json()
        city_lat=city_data["coord"]["lat"]
        city_lon=city_data["coord"]["lon"]
        city_temp=city_data["main"]["temp"]
        city_hum=city_data["main"]["humidity"]
        city_pr=city_data["main"]["pressure"]
        city_ws=city_data["wind"]["speed"]
        city_cl=city_data["clouds"]["all"]
        city_cc=city_data["sys"]["country"]
        city_date=city_data["dt"]

        citi_weather.append({"city":city, 
        "latitude":city_lat,
        "longitude":city_lon,
        "temperature":city_temp,
        "humidity":city_hum,
        "pressure":city_pr,
        "wind speed":city_ws,
        "clouds":city_cl,
        "country":city_cc,
        "Date":city_date
})
    except:
        print('city not found')
    pass
# Out:
# processing record for the city diego de almagro
# processing record for the city flinders
# processing record for the city cape town
# processing record for the city gitega
# processing record for the city nouadhibou
# processing record for the city illoqqortoormiut
# city not found
# processing record for the city hofn
# processing record for the city hermanus
# processing record for the city palu
# processing record for the city busselton
# processing record for the city porto walter
# processing record for the city karauzyak
# city not found
# processing record for the city punta arenas
# processing record for the city mataura
# processing record for the city puerto leguizamo
# processing record for the city barentsburg
# city not found
# processing record for the city ukiah
# processing record for the city gwadar
# processing record for the city ilulissat
# processing record for the city albany
# processing record for the city lengshuijiang
# processing record for the city clyde river
# processing record for the city tsihombe
# city not found
# processing record for the city haines junction
# processing record for the city new norfolk
# processing record for the city hobart
# processing record for the city chuy
# processing record for the city yumen
# processing record for the city faanui
# processing record for the city jujuy
# city not found
# processing record for the city sioux lookout
# processing record for the city san vicente
# processing record for the city waingapu
# processing record for the city arraial do cabo
# processing record for the city barrow
# processing record for the city atambua
# processing record for the city voh
# processing record for the city saint-philippe
# processing record for the city kaele
# processing record for the city tuatapere
# processing record for the city olafsvik
# city not found
# processing record for the city shache
# processing record for the city ramotswa
# processing record for the city bredasdorp
# processing record for the city tiksi
# processing record for the city gushikawa
# processing record for the city swan river
# processing record for the city ushuaia
# processing record for the city chokurdakh
# processing record for the city bambous virieux
# processing record for the city souillac
# processing record for the city birjand
# processing record for the city tumannyy
# city not found
# processing record for the city kaitangata
# processing record for the city kudymkar
# processing record for the city mahebourg
# processing record for the city roald
# processing record for the city asfi
# city not found
# processing record for the city rikitea
# processing record for the city brae
# processing record for the city ponta do sol
# processing record for the city plackovci
# city not found
# processing record for the city ribeira grande
# processing record for the city bluff
# processing record for the city comodoro rivadavia
# processing record for the city burkhala
# city not found
# processing record for the city tabuk
# processing record for the city nikolskoye
# processing record for the city beringovskiy
# processing record for the city wadi maliz
# processing record for the city samusu
# city not found
# processing record for the city namibe
# processing record for the city atuona
# processing record for the city saldanha
# processing record for the city castro
# processing record for the city victoria
# processing record for the city bethel
# processing record for the city tezu
# processing record for the city hithadhoo
# processing record for the city taolanaro
# city not found
# processing record for the city butaritari
# processing record for the city newnan
# processing record for the city olinda
# processing record for the city port hawkesbury
# processing record for the city zabid
# processing record for the city cabo san lucas
# processing record for the city aleksandrov gay
# processing record for the city port alfred
# processing record for the city gambang
# processing record for the city jamestown
# processing record for the city hilo
# processing record for the city oshkosh
# processing record for the city atikokan
# processing record for the city qiqihar
# processing record for the city cidreira
# processing record for the city hunchun
# processing record for the city salinas
# processing record for the city panaba
# processing record for the city ahuimanu
# processing record for the city avera
# processing record for the city marystown
# processing record for the city lebu
# processing record for the city guerrero negro
# processing record for the city chapais
# processing record for the city mar del plata
# processing record for the city puerto ayora
# processing record for the city dikson
# processing record for the city belushya guba
# city not found
# processing record for the city tuktoyaktuk
# processing record for the city camacha
# processing record for the city greenville
# processing record for the city kapaa
# processing record for the city gobabis
# processing record for the city cabedelo
# processing record for the city nanortalik
# processing record for the city voznesenye
# processing record for the city raudeberg
# processing record for the city nizhneyansk
# city not found
# processing record for the city katsuura
# processing record for the city upernavik
# processing record for the city kupang
# processing record for the city broome
# processing record for the city lorengau
# processing record for the city vaini
# processing record for the city inirida
# processing record for the city pangnirtung
# processing record for the city aguimes
# processing record for the city saleaula
# city not found
# processing record for the city cayenne
# processing record for the city port elizabeth
# processing record for the city norman wells
# processing record for the city urambo
# processing record for the city port blair
# processing record for the city akyab
# city not found
# processing record for the city vaitupu
# city not found
# processing record for the city kodiak
# processing record for the city zyryanka
# processing record for the city kahului
# processing record for the city carnarvon
# processing record for the city umm ruwabah
# city not found
# processing record for the city laguna
# processing record for the city yellowknife
# processing record for the city sao joao da barra
# processing record for the city husavik
# processing record for the city east london
# processing record for the city ondjiva
# processing record for the city mys shmidta
# city not found
# processing record for the city avarua
# processing record for the city tripoli
# processing record for the city maragogi
# processing record for the city juneau
# processing record for the city ararat
# processing record for the city coruripe
# processing record for the city luwingu
# processing record for the city saint george
# processing record for the city limerick
# processing record for the city college
# processing record for the city lolua
# city not found
# processing record for the city boddam
# processing record for the city jutai
# processing record for the city iqaluit
# processing record for the city yomitan
# city not found
# processing record for the city zhongxing
# processing record for the city vestmannaeyjar
# processing record for the city bairiki
# city not found
# processing record for the city praya
# processing record for the city simao
# processing record for the city xiamen
# processing record for the city oktyabrskoye
# processing record for the city henties bay
# processing record for the city kayiry
# processing record for the city australind
# processing record for the city moorhead
# processing record for the city union de san antonio
# processing record for the city taulov
# processing record for the city saint albans
# processing record for the city grand centre
# city not found
# processing record for the city charters towers
# processing record for the city ayan
# processing record for the city umm kaddadah
# processing record for the city slave lake
# processing record for the city cedar city
# processing record for the city aripuana
# processing record for the city kashi
# city not found
# processing record for the city vaasa
# processing record for the city port moresby
# processing record for the city zharkent
# processing record for the city inhambane
# processing record for the city northam
# processing record for the city bada
# processing record for the city lazaro cardenas
# processing record for the city ribeira brava
# processing record for the city plouzane
# processing record for the city katyuzhanka
# processing record for the city alta floresta
# processing record for the city balaka
# processing record for the city nguiu
# city not found
# processing record for the city martinsburg
# processing record for the city deputatskiy
# processing record for the city tignere
# processing record for the city mildura
# processing record for the city djougou
# processing record for the city pisco
# processing record for the city verkh-usugli
# processing record for the city banda aceh
# processing record for the city guatire
# processing record for the city prince rupert
# processing record for the city privas
# processing record for the city puri
# processing record for the city matay
# processing record for the city petropavlovsk-kamchatskiy
# processing record for the city trapani
# processing record for the city sitka
# processing record for the city shenjiamen
# processing record for the city sur
# processing record for the city dawei
# processing record for the city nanakuli
# processing record for the city kangaatsiaq
# processing record for the city skjervoy
# processing record for the city palm valley
# processing record for the city sao jose da coroa grande
# processing record for the city gulshat
# city not found
# processing record for the city kirensk
# processing record for the city marquette
# processing record for the city rosarito
# processing record for the city kuvandyk
# processing record for the city lake cowichan
# processing record for the city srednekolymsk
# processing record for the city pevek
# processing record for the city achalpur
# processing record for the city udachnyy
# processing record for the city mogadishu
# processing record for the city chistogorskiy
# processing record for the city ardistan
# city not found
# processing record for the city san-pedro
# processing record for the city tsaratanana
# processing record for the city riyadh
# processing record for the city knysna
# processing record for the city biak
# processing record for the city port hardy
# processing record for the city fukue
# processing record for the city ambon
# processing record for the city havoysund
# processing record for the city port-gentil
# processing record for the city idah
# processing record for the city oranjemund
# processing record for the city varzea da palma
# processing record for the city killybegs
# processing record for the city rawson
# processing record for the city tessalit
# processing record for the city seddon
# processing record for the city carballo
# processing record for the city esperance
# processing record for the city leh
# processing record for the city micheweni
# processing record for the city lewiston
# processing record for the city macaboboni
# city not found
# processing record for the city valparaiso
# processing record for the city bubaque
# processing record for the city buala
# processing record for the city havre-saint-pierre
# processing record for the city livingstone
# processing record for the city olden
# processing record for the city esqueda
# processing record for the city tocopilla
# processing record for the city zhuhai
# processing record for the city yamada
# processing record for the city broken hill
# processing record for the city aitape
# processing record for the city amursk
# processing record for the city kharitonovo
# processing record for the city port keats
# processing record for the city lyngseidet
# processing record for the city gamba
# processing record for the city mercedes
# processing record for the city cape elizabeth
# city not found
# processing record for the city saint-georges
# processing record for the city manaure
# processing record for the city vestmanna
# processing record for the city wadi musa

# %%
#json.dumps(date.date.now().isoformat())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-931063337b41> in <module>()
# ----> 1 json.dumps(date.date.now().isoformat())
#
# NameError: name 'date' is not defined

# %%
#create csv file"cities" in a folder named output_file
#convert to dataframe first and save as csv file
city_data_df=pd.DataFrame(citi_weather)
latitude= city_data_df["latitude"]
longitude=city_data_df["longitude"]
temperature=city_data_df["temperature"]
humidity=city_data_df["humidity"]
pressure=city_data_df["pressure"]
wind_speed=city_data_df["wind speed"]
clouds=city_data_df["clouds"]
country=city_data_df["country"]
date=city_data_df['Date'] 

city_data_df.head()        


#city_data_df.to_csv("output_data/cities.csv")
# Out:
#          Date              city  clouds country  humidity  latitude  \
# 0  1533640643  diego de almagro      12      CL        97    -26.39
# 1  1533639600          flinders      20      AU        69    -34.58
# 2  1533636000         cape town      75      ZA        66    -33.93
# 3  1533640644            gitega      24      BI        45     -3.43
# 4  1533639600        nouadhibou      75      MR        83     20.93
#
#    longitude  pressure  temperature  wind speed
# 0     -70.05    921.17        46.71        1.16
# 1     150.85   1012.00        51.80       23.04
# 2      18.42   1026.00        55.40        8.05
# 3      29.93    838.49        78.94        5.53
# 4     -17.03   1013.00        73.40        4.70

# %%
city_data_df.dtypes
# Out:
# Date             int64
# city            object
# clouds           int64
# country         object
# humidity         int64
# latitude       float64
# longitude      float64
# pressure       float64
# temperature    float64
# wind speed     float64
# dtype: object

# %%
# Build a scatter plot for each data type
plt.scatter(city_data_df["latitude"], city_data_df["temperature"], marker="o", color="blue")

# Incorporate the other graph properties
plt.title("Temperature of World Cities")
plt.ylabel("Temperature (Farnheit)")
plt.xlabel("Latitide")
plt.grid(True)

# Save the figure
plt.savefig("temperatureofWorldCities.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-68674b48b5cb> in <module>()
#       1 # Build a scatter plot for each data type
# ----> 2 plt.scatter(city_data["latitude"], city_data["temperature"], marker="o", color="blue")
#       3
#       4 # Incorporate the other graph properties
#       5 plt.title("Temperature of World Cities")
#
# KeyError: 'latitude'

# %%
x_axis=city_data_df["latitude"]
y_axis=city_data_df["temperature"]
plt.scatter((x_axis,y_axis)
plt.xlabel('latitude')
plt.ylabel('Temperature (F)')
plt.title('Latitude vs Temperature' )
plt.savefig('TemperatureofWorldCities.png')
plt.show()
# Out:
#   File "<ipython-input-55-8d796d7c7da4>", line 4
#     plt.xlabel('latitude')
#       ^
# SyntaxError: invalid syntax

# %%
#converted_time_=[]
#for date in city_data_df:
    # https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
    # http://strftime.org/
    #date = datetime.strptime(raw_time, "%a %b %d %H:%M:%S %z %Y")
    #converted_timestamps.append(converted_time)

# %%
# Force column order
city_data_df = city_data_df[["city","country","latitude","longitude","temperature","humidity","clouds","wind speed"]]
city_data_df.head()
# Out:
#                city country  latitude  longitude  temperature  humidity  \
# 0  diego de almagro      CL    -26.39     -70.05        46.71        97
# 1          flinders      AU    -34.58     150.85        51.80        69
# 2         cape town      ZA    -33.93      18.42        55.40        66
# 3            gitega      BI     -3.43      29.93        78.94        45
# 4        nouadhibou      MR     20.93     -17.03        73.40        83
#
#    clouds  wind speed
# 0      12        1.16
# 1      20       23.04
# 2      75        8.05
# 3      24        5.53
# 4      75        4.70

# %%
city_data_df.to_csv("output_data/cities.csv", encoding="utf-8")

# %%
x_axis=city_data_df["latitude"]
y_axis=city_data_df["temperature"]
plt.scatter((x_axis,y_axis)
plt.xlabel('latitude')
plt.ylabel('Temperature(F)')
plt.title('Latitude vs Temperature' )
plt.savefig('TemperatureofWorldCities.png')
plt.show()
# Build a scatter plot for each data type
#plt.scatter(city["Lat"], City_Sample["Temp"], marker="o", color = 'blue')

# # Incorporate the other graph properties
#plt.title("City Altitude vs Max Temperature " + str(Date))
#plt.ylabel("Max Temperature (F)")
#plt.xlabel("Latitude")
#plt.yticks(np.arange(-40, 120, 20))
#plt.grid(True)
#sns.set_style('darkgrid')
# Out:
#   File "<ipython-input-54-924f036c94a0>", line 4
#     plt.xlabel('latitude')
#       ^
# SyntaxError: invalid syntax

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-c94eaf4f8168> in <module>()
# ----> 1 Date = date.now().strftime("(%m/%d/%Y)")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'now'

# %%
#p=tucson
#https://openweathermap.org/api
#varibale, fileame, keyanme
# list for response results
#lat=[]
#lon = []
#city = []
#country = []
#temp= []
#humidity=[]
#citi_weather will store all these parameter as one dictionary

weather_key=api_keys.api_key
URL="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_key
citi_weather=[]

for i, city in enumerate(cities):
    city_URL=URL+'&q='+city
    
    print('processing record for the city %s.URL %s'%(city, city_URL))
    
    try:
        city_data=requests.get(city_URL).json()
        city_lat=city_data["coord"]["lat"]
        city_lon=city_data["coord"]["lon"]
        city_temp=city_data["main"]["temp"]
        city_hum=city_data["main"]["humidity"]
        city_pr=city_data["main"]["pressure"]
        city_ws=city_data["wind"]["speed"]
        city_cl=city_data["clouds"]["all"]
        city_cc=city_data["sys"]["country"]
        city_date=city_data["dt"]
        
        
        citi_weather.append({"city":city, 
                             "latitude":city_lat,
                             "longitude":city_lon,
                             "temperature":city_temp,
                             "humidity":city_hum,
                             "pressure":city_pr,
                             "wind speed":city_ws,
                             "clouds":city_cl,
                             "country code":citi_cc,
                             "Date":city_date})
    except:
        print('city not found')
        pass
    

#* Temperature (F) vs. Latitude
#* Humidity (%) vs. Latitude
#* Wind Speed (mph) vs. Latitude

#* Cloudiness (%) vs. Latitude

# add closest city and country column
#location_data['closest_city'] = ""
#location_data['country'] = ""

# %%
#find and add closest city and country code
#for index, row in location_data.iterrows():
    #lat = row['rand_lat']
    #lng = row['rand_lng']
    #location_data.iat(index, 'closest_city', citipy.nearest_city(lat, lng).city_name)
    #location_data.iat(index, 'country', citipy.nearest_city(lat, lng).country_code)
    #print(lat, lng)

# %%
# delete repeated cities and find unique city count
location_data = location_data.drop_duplicates(['closest_city', 'country'])
location_data = location_data.dropna()
len(location_data['closest_city'].value_counts())

# %%
#preview data
location_data.head()

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
